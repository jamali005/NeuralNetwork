# %% [markdown]
# # Homework3: Instructions

# %% [markdown]
# 1. Write down 3 questions and their brief answers on the reading material. [2 Points]

# %% [markdown]
# 2. From the Chapter 2 Haykin’s book solve 2.1 [8 Points]

# %% [markdown]
# 1. what is the main difference between delta rule and Hebbian learning?
#
# ### A: in Hebbian the weight can be updated while performing.

# %% [markdown]
# 3. Using the parameters from the ex 2.10 ( Chapter 2 Haykin’s book ) programm competetive learning. Hint: use a standard network of neurons followed by a max-net implementation! keyword is: max-net [8 Points]

# %% [markdown]
# The constructed network will be a standard perceptron network followed by max-net for the induced field values ($v$).
# Assume the network has 4 inputs and 4 outputs, and taking the weight of lateral connections to be $-\epsilon$, the induced field will be the sum of the perceptron plus the lateral connections between the induced field neurons as follows:
#
# $
# \begin{bmatrix}
#        v1_{n} \\[0.3em]
#        v2_{n}   \\[0.3em]
#        v3_{n}  \\[0.3em]
#        v4_{n} \\
#      \end{bmatrix}$
# =
# $
# \begin{bmatrix}
#        1 & -\epsilon & -\epsilon & -\epsilon  \\[0.3em]
#        -\epsilon & 1         & -\epsilon &-\epsilon \\[0.3em]
#        -\epsilon  & -\epsilon  &1   & -\epsilon \\[0.3em]
#        -\epsilon & -\epsilon & -\epsilon & 1
#      \end{bmatrix}
#      \begin{bmatrix}
#        v1_{n-1} \\[0.3em]
#        v2_{n-1}   \\[0.3em]
#        v3_{n-1}  \\[0.3em]
#        v4_{n-1} \\
#      \end{bmatrix}$
# +
# $
# \begin{bmatrix}
#        \sum_j w_{ji}x_i \\[0.3em]
#        \sum_j w_{ji}x_i   \\[0.3em]
#        \sum_j w_{ji}x_i  \\[0.3em]
#        \sum_j w_{ji}x_i \\
#      \end{bmatrix}
# $
#
# and the final output $y$ becomes :
#
# $
# \begin{bmatrix}
#        y1_{n} \\[0.3em]
#        y2_{n}   \\[0.3em]
#        y3_{n}  \\[0.3em]
#        y4_{n} \\
#      \end{bmatrix}$
# =
# $
# \begin{bmatrix}
#        \varphi (v1_{n}) \\[0.3em]
#        \varphi (v2_{n})   \\[0.3em]
#        \varphi (v3_{n})  \\[0.3em]
#        \varphi (v4_{n}) \\
#      \end{bmatrix}$

# %% [markdown]
# 4. A simple network is given below (from lecture slides). You have to update the weights once using Boltzmann learning for this network. Please do calculations by hand or by using Python.
# ![network.png](attachment:network.png)
# Use random numbers to initialise the weights. For training use a training set as [(0, 1), (1,
# 0)] or any training set of your choice. [8 Points]

# %% [markdown]
# In order to update the wights using Boltzmann learning for the above neural network, Restriced Boltzmann Machine method is used where we have one visible layer and one hidden layer.
#
# The steps will be as follows:
#
# 1. Setting initial weights with random values.
# 2. Find the probability distribution for all the the hidden units (using Sigmoid function as activation function $\varphi (\sum \sum hv $), biases are assumed to be equal to 0. From it, estimate samples for hidden values, $\textbf{Gibbs Sampling}$ can be used for that. This step describes the $\textbf{Clamping phase}$.
# 3. Apply previous step for all visible units to obtain sampled visible values.
# 4. From the obtained new visible samples update the hidden values (same as step 2 but with the sampled visible values). This step describes the $\textbf{Free Running phase}$.
# 5. Add the following to the weight \:
#
# $$\Delta w = \eta(<h_0v_0> - <h_1v_1>) $$
#
# ###### The following code implements the steps above to find the updated weight:
# $
# w_0 =
# \begin{bmatrix}
#        0.19646919 & -0.21386067 & -0.27314855   \\[0.3em]
#        0.05131477 & 0.21946897 & -0.07689354 \\[0.3em]
#      \end{bmatrix}$
#
#
#  $w_1 =
#  \begin{bmatrix}
#        4.57559832 & 1.16728523 & -4.90580347   \\[0.3em]
#        -5.0093081 & -0.96952198 & 4.90125028 \\[0.3em]
#      \end{bmatrix}$

# %%
"""
 Restricted Boltzmann Machine (RBM)
 References :
   - Y. Bengio, P. Lamblin, D. Popovici, H. Larochelle: Greedy Layer-Wise
   Training of Deep Networks, Advances in Neural Information Processing
   Systems 19, 2007
   - DeepLearningTutorials
   https://github.com/lisa-lab/DeepLearningTutorials
"""
import numpy


numpy.seterr(all='ignore')

def sigmoid(x):
    return 1. / (1 + numpy.exp(-x))


class RBM(object):
    def __init__(self, input=None, n_visible=2, n_hidden=3, \
        W=None, hbias=None, vbias=None, numpy_rng=None):
        
        self.n_visible = n_visible  # num of units in visible (input) layer
        self.n_hidden = n_hidden    # num of units in hidden layer

        if numpy_rng is None:
            numpy_rng = numpy.random.RandomState(1234)


        if W is None:
            a = 1. / n_visible
            initial_W = numpy.array(numpy_rng.uniform(  # initialize W uniformly
                low=-a,
                high=a,
                size=(n_visible, n_hidden)))

            W = initial_W

        if hbias is None:
            hbias = numpy.zeros(n_hidden)  # initialize h bias 0

        if vbias is None:
            vbias = numpy.zeros(n_visible)  # initialize v bias 0


        self.numpy_rng = numpy_rng
        self.input = input
        self.W = W
        self.hbias = hbias
        self.vbias = vbias
        print("initial weight=",self.W)
        # self.params = [self.W, self.hbias, self.vbias]


    def contrastive_divergence(self, lr=0.1, k=1, input=None):
        if input is not None:
            self.input = input
        
        ''' CD-k '''
        ph_mean, ph_sample = self.sample_h_given_v(self.input)

        chain_start = ph_sample

        for step in range(k):
            if step == 0:
                nv_means, nv_samples,\
                nh_means, nh_samples = self.gibbs_hvh(chain_start)
            else:
                nv_means, nv_samples,\
                nh_means, nh_samples = self.gibbs_hvh(nh_samples)

        # chain_end = nv_samples


        self.W += lr * (numpy.dot(self.input.T, ph_sample)
                        - numpy.dot(nv_samples.T, nh_means))
        self.vbias += lr * numpy.mean(self.input - nv_samples, axis=0)
        self.hbias += lr * numpy.mean(ph_sample - nh_means, axis=0)
        #print("W=",self.W)
        # cost = self.get_reconstruction_cross_entropy()
        # return cost


    def sample_h_given_v(self, v0_sample):
        h1_mean = self.propup(v0_sample)
        h1_sample = self.numpy_rng.binomial(size=h1_mean.shape,   # discrete: binomial
                                       n=1,
                                       p=h1_mean)

        return [h1_mean, h1_sample]


    def sample_v_given_h(self, h0_sample):
        v1_mean = self.propdown(h0_sample)
        v1_sample = self.numpy_rng.binomial(size=v1_mean.shape,   # discrete: binomial
                                            n=1,
                                            p=v1_mean)
        
        return [v1_mean, v1_sample]

    def propup(self, v):
        pre_sigmoid_activation = numpy.dot(v, self.W) + self.hbias
        return sigmoid(pre_sigmoid_activation)

    def propdown(self, h):
        pre_sigmoid_activation = numpy.dot(h, self.W.T) + self.vbias
        return sigmoid(pre_sigmoid_activation)


    def gibbs_hvh(self, h0_sample):
        v1_mean, v1_sample = self.sample_v_given_h(h0_sample)
        h1_mean, h1_sample = self.sample_h_given_v(v1_sample)

        return [v1_mean, v1_sample,
                h1_mean, h1_sample]
    

    def get_reconstruction_cross_entropy(self):
        pre_sigmoid_activation_h = numpy.dot(self.input, self.W) + self.hbias
        sigmoid_activation_h = sigmoid(pre_sigmoid_activation_h)
        
        pre_sigmoid_activation_v = numpy.dot(sigmoid_activation_h, self.W.T) + self.vbias
        sigmoid_activation_v = sigmoid(pre_sigmoid_activation_v)

        cross_entropy =  - numpy.mean(
            numpy.sum(self.input * numpy.log(sigmoid_activation_v) +
            (1 - self.input) * numpy.log(1 - sigmoid_activation_v),
                      axis=1))
        
        return cross_entropy

    def reconstruct(self, v):
        h = sigmoid(numpy.dot(v, self.W) + self.hbias)
        reconstructed_v = sigmoid(numpy.dot(h, self.W.T) + self.vbias)
        return reconstructed_v
    
        

def test_rbm(learning_rate=0.1, k=1, training_epochs=1000):
    data = numpy.array([[0,1],
                        [1,0]])


    print("training_data =",data)
    rng = numpy.random.RandomState(123)

    # construct RBM
    rbm = RBM(input=data, n_visible=2, n_hidden=3, numpy_rng=rng)

    # train
    for epoch in range(training_epochs):
        rbm.contrastive_divergence(lr=learning_rate, k=k)
        cost = rbm.get_reconstruction_cross_entropy()
        #print(sys.stderr, 'Training epoch %d, cost is ' % epoch, cost)


    # test
    v = numpy.array([[0,1],
                     [1,0]])
    print("updated_weight=",rbm.W)
    print("Reconstructed_visibles=",rbm.reconstruct(v))
    


test_rbm()
# Out:
# training_data = [[0 1]
#  [1 0]]
# initial weight= [[ 0.19646919 -0.21386067 -0.27314855]
#  [ 0.05131477  0.21946897 -0.07689354]]
# updated_weight= [[ 4.57559832 -1.16728523 -4.90580347]
#  [-5.0093081  -0.96952198  4.90125028]]
# Reconstructed_visibles= [[0.00613433 0.99147954]
#  [0.98607705 0.00690514]]

# %% [markdown]
# 5. (if VCdim got covered in class) Consider the space of instances X corresponding to all points in the x, y plane. Give the VC dimension of the following hypothesis spaces:
# a. Hr = the set of all rectangles in the x,y plane. i.e. Hr = {((a<x<b) ^(c<y<d)) | a, b, c, d є IR}
# b. Hc = the set of all circles in the x,y plane. Points inside the circle are classified as positive examples.
# c. Ht = the set of all triangle in the x,y plane. Points inside the triangle are classified as positive examples. [8 Points]

# %% [markdown]
# ### a.
#
# For the space of instances corresponding to all points in the x,y plane:
#
# * If the points $\textbf{inside the rectangle}$ are assumed to be positive, then the VC dimension $\textbf{H=4}$.
# * If we're $\textbf{free to choose if points inside or outside are positive}$, then the VC dimension $\textbf{H=5}$.
#
# ### b.
# * For set of all circles in the x,y plane: we find that the circle classifers will allow to classify up to 3 data points, hence VC dimension $\textbf{H=3}$. Also,  circles are convex, therefore in a case of 4 data points it may be not possible to label the inside point negative and the outside points as positive, so the points inside the circle is considered positive.
#
# ### c.
# * For set of all triangles in the x,y plane: we find that the VC dimension $\textbf{H=7}$.Also, in the case of 8 points it may be not possible to classify alternatively between positive and negative, therefore H = 7.
