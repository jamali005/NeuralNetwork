# %% [markdown]
# # Homework4: Instructions

# %% [markdown]
# 1) Write down 3 questions and their brief answers on the reading material. [2 Points]

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 2) SVM 1-D Understanding
#
# The graphs below represent three different one-dimensional classification (dichotomization) tasks (along a sketched x-axis, dash means 'no data point').
#
# What is the lowest-order polynomial decision function that can correctly classify the given data? Black dots denote class 1 with target function value y1 = +1 and white dots depict class 2 with targets y2 = -1. What are the decision boundaries?
# ![1D_classifiecation.jpg](attachment:1D_classifiecation.jpg) [8 points]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
# %matplotlib inline

# %% [markdown]
# ## First Case : a

# %%
## dataPoints
X = np.array([[1,9],[2,8],[5,3],[6,0],[9,9],[10,5],[11,6]])
## Labels
y = np.array([1,1,0,0,1,1,1])

# %% [markdown]
# #### training the algorithm

# %% [markdown]
# The fit method of SVC class is called to train the algorithm on the training data, which is passed as a parameter to the fit method.

# %%
svclassifier = SVC(kernel='linear')
svclassifier.fit(X, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
w =svclassifier.coef_[0]
I = svclassifier.intercept_
slope = -w[0]/w[1]
intercept = I[0]/w[1]
x1 = np.linspace(1,11,100)
y1 = slope*x1 - intercept


plt.plot(x1,y1)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

xx = np.linspace(-5, 5)
yy = slope * xx - (svclassifier.intercept_[0]) / w[1]

margin = 1 / np.sqrt(np.sum(svclassifier.coef_ ** 2))
yy_down = y1 - np.sqrt(1 + slope ** 2) * margin
yy_up = y1 + np.sqrt(1 + slope ** 2) * margin

plt.plot(x1, yy_down, 'k--')
plt.plot(x1, yy_up, 'k--')

# %% [markdown]
# ## Second Case :

# %%
## dataPoints
X = np.array([[1,0],[2,0],[5,0],[6,0],[9,0],[10,0],[11,0]])
## Labels
y = np.array([1,1,0,0,1,1,1])

# %%
svclassifier1 = SVC(kernel='linear',C=1)
svclassifier1.fit(X, y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
w =svclassifier1.coef_[0]
I = svclassifier1.intercept_
if(w[1] != 0):
    slope = -w[0]/w[1]
    intercept = I[0]/w[1]
    x1 = np.linspace(1,11,100)
    y1 = slope*x1 - intercept


    plt.plot(x1,y1)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

    xx = np.linspace(-5, 5)
    yy = slope * xx - (svclassifier1.intercept_[0]) / w[1]

    margin = 1 / np.sqrt(np.sum(svclassifier1.coef_ ** 2))
    yy_down = y1 - np.sqrt(1 + slope ** 2) * margin
    yy_up = y1 + np.sqrt(1 + slope ** 2) * margin

    plt.plot(x1, yy_down, 'k--')
    plt.plot(x1, yy_up, 'k--')
else:
    print("it's impossible to find any hyperplane which satisfies \"No in-sample errors\"")
    plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
# Out:
# it's impossible to find any hyperplane which satisfies "No in-sample errors"

# %% [markdown]
# ## Case 3

# %%
## dataPoints
X = np.array([[1],[2],[5],[6],[9],[10],[11]])
## Labels
y = np.array([1,1,0,0,1,1,1])

# %%
def svc(n):
    svclassifier = SVC(kernel='poly',degree=n,gamma='scale')
    svclassifier.fit(X, y)
    y_pred = svclassifier.predict(X)
    pri
    error_rate = sum(y_pred != y)
    return error_rate

# %%
error = 1
n=1
while(error != 0):
    error = svc(n)
    print("n = ",n," error rate = ",error)
    n = n + 1
# Out:
# n =  1  error rate =  2
# n =  2  error rate =  2
# n =  3  error rate =  2
# n =  4  error rate =  2
# n =  5  error rate =  2
# n =  6  error rate =  2
# n =  7  error rate =  2
# n =  8  error rate =  2
# n =  9  error rate =  2
# n =  10  error rate =  2
# n =  11  error rate =  2
# n =  12  error rate =  2
# n =  13  error rate =  2
# n =  14  error rate =  5
# n =  15  error rate =  5
# n =  16  error rate =  2
# n =  17  error rate =  5
# n =  18  error rate =  2

# %% [markdown]
# 3) In Haykin 2ed, P6.14 shows a set of data points corresponding to two classes C1 and C2. Both coordinates x1 and x2 range from -1 to +1. Using the radial-basis function kernel
#
# K(x,t) = exp(-(|| x - t ||^2))
# construct the optimal hyperplane for the following data set.
#
# mypositive=[
# -1/2 3/4+1/16
# -1/2 3/4-1/16
# -3/8 3/4+1/16
# -3/8 3/4-1/16
# -1/4 3/4+1/16
# -1/4 3/4-1/16
# -1/8 1/2+1/16
# -1/8 3/4
# 0 1/2
# 0 3/4
# 1/8 -3/4-3/16
# 1/8 -3/4
# 1/8 -1/2-1/16
# 1/8 -1/2+1/16
# 1/8 1/4
# 1/8 1/4+3/16
# 1/8 1/2+2/16
# 1/4 -3/4-2/16
# 1/4 -1/2-2/16
# 1/4 -1/16
# 1/4 2/16
# 1/4 1/4+1/16
# 1/4 1/2
# 3/8 -1/4-2/16
# 3/8 -3/16
# 3/8 1/16
# 3/8 1/4
# 1/2 -1/16
# ];
#
# mynegative=[ -1/2 1/2
# -3/8 -1/2
# -3/8 1/4+1/16
# -3/8 1/2
# -1/4 -3/4-1/16
# -1/4 -3/4+1/16
# -1/4 -3/16
# -1/4 2/16
# -1/4 1/4+1/16
# -1/4 1/2-1/16
# -1/8 -3/4-2/16
# -1/8 -3/4
# -1/8 -1/2-1/16
# -1/8 -1/4-2/16
# -1/8 -1/4
# -1/8 3/16
# -1/8 1/4+1/16
# 0 -1/4
# 0 1/16
# 1/16 -1/16
# ];
#
# You result classification should looks as the following:
# ![svm_result.jpg](attachment:svm_result.jpg)

# %%
mypositive=[[-1/2 ,3/4+1/16],
                     [-1/2 ,3/4-1/16],
                     [-3/8 ,3/4+1/16],
                     [-3/8 ,3/4-1/16],
                     [-1/4 ,3/4+1/16],
                     [-1/4 ,3/4-1/16],
                     [-1/8 ,1/2+1/16],
                     [-1/8 ,3/4] ,
                     [0 ,1/2] ,
                     [0 ,3/4] ,
                     [1/8 ,-3/4-3/16],
                     [1/8 ,-3/4],
                     [1/8 ,-1/2-1/16],
                     [1/8 ,-1/2+1/16], 
                     [1/8 ,1/4],
                     [1/8 ,1/4+3/16],
                     [1/8 ,1/2+2/16],
                     [1/4 ,-3/4-2/16],
                     [1/4 ,-1/2-2/16],
                     [1/4 ,-1/16],
                     [1/4 ,2/16],
                     [1/4 ,1/4+1/16],
                     [1/4 ,1/2],
                     [3/8 ,-1/4-2/16],
                     [3/8 ,-3/16],
                     [3/8 ,1/16],
                     [3/8 ,1/4],
                     [1/2 ,-1/16]]

# %%
nb_el_pos = np.shape(mypositive)[0]

# %%
mynegative=[[-1/2 ,1/2] ,
                     [-3/8 ,-1/2] ,
                     [-3/8 ,1/4+1/16] ,
                     [-3/8 ,1/2 ],
                     [-1/4 ,-3/4-1/16] ,
                     [-1/4 ,-3/4+1/16] ,
                     [-1/4 ,-3/16] ,
                     [-1/4 ,2/16] ,
                     [-1/4 ,1/4+1/16] ,
                     [-1/4 ,1/2-1/16] ,
                     [-1/8 ,-3/4-2/16] ,
                     [-1/8 ,-3/4] ,
                     [-1/8 ,-1/2-1/16] ,
                     [-1/8 ,-1/4-2/16] ,
                     [-1/8 ,-1/4] ,
                     [-1/8 ,3/16] ,
                     [-1/8 ,1/4+1/16] ,
                     [0 ,-1/4] ,
                     [0 ,1/16] ,
                     [1/16 ,-1/16] ]

# %%
nb_el_neg = np.shape(mynegative)[0]

# %%
for neg in mynegative:
    mypositive.append(neg)

# %%
X = mypositive

# %%
np.shape(X)

# %%
labelsPositive = np.ones(nb_el_pos)
labelsNegative = -np.ones(nb_el_neg)

# %%
Y = np.hstack((labelsPositive,labelsNegative))

# %%
Y.shape

# %%
svclassifier = SVC(kernel='rbf',gamma=np.sqrt(1/2))
svclassifier.fit(X, Y)

# %%
y_pred = svclassifier.predict(X)
error_rate = sum(y_pred != Y)
error_rate

# %%
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    X = np.array(X)
    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'white')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=cmap(idx),
                    marker=markers[idx], label=cl)

# %%
# Create a SVC classifier using an RBF kernel
svm = SVC(kernel='rbf', random_state=0, gamma=1/np.sqrt(2), C=1)
# Train the classifier
svm.fit(X, Y)

# Visualize the decision boundaries
plot_decision_regions(X, Y, classifier=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
