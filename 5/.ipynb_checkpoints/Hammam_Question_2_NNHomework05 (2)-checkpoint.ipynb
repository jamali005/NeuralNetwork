# %% [markdown]
# # Homework4: Instructions

# %% [markdown]
# 1) Write down 3 questions and their brief answers on the reading material. [2 Points]

# %% [markdown]
# YOUR ANSWER HERE

# %% [markdown]
# 2) SVM 1-D Understanding
#
# The graphs below represent three different one-dimensional classification (dichotomization) tasks (along a sketched x-axis, dash means 'no data point').
#
# What is the lowest-order polynomial decision function that can correctly classify the given data? Black dots denote class 1 with target function value y1 = +1 and white dots depict class 2 with targets y2 = -1. What are the decision boundaries?
# ![1D_classifiecation.jpg](attachment:1D_classifiecation.jpg) [8 points]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC
# %matplotlib inline

# %% [markdown]
# ## First Case : a

# %%
#The idea is make x 2-dimensional instead of 1 and in the second dimension we raise x to certain degree
#that makes the data linearly separable 

def svmc1(d):
    ## dataPoints
    X = np.array([[1,1],[2,2**d],[5,5**d],[6,6**d],[9,9**d],[10,10**d],[11,11**d]])
    ## Labels
    y = np.array([1,1,0,0,1,1,1])


    svclassifier = SVC(kernel='linear',C=1)
    svclassifier.fit(X, y)


    w =svclassifier.coef_[0]
    I = svclassifier.intercept_
    slope = -w[0]/w[1]
    intercept = I[0]/w[1]
    x1 = np.linspace(1,11,100)
    y1 = slope*x1 - intercept



    plt.plot(x1,y1)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='autumn')

    xx = np.linspace(-5, 5)
    yy = slope * xx - (svclassifier.intercept_[0]) / w[1]

    margin = 1 / np.sqrt(np.sum(svclassifier.coef_ ** 2))
    #print(margin)

    yy_down = y1 - np.sqrt(1 + slope ** 2) * margin
    yy_up = y1 + np.sqrt(1 + slope ** 2) * margin

    print("margin size=",margin)
    
    print("error (number of points inside the margin=)","To be calculated, lol")
    plt.plot(x1, yy_down, 'k--')
    plt.plot(x1, yy_up, 'k--')
    plt.grid()
    plt.show()

for i in range(1,4):
    print("for degree=",i)
    svmc1(i)
# Out:
# for degree= 1
# margin size= 1197999432892430.2
# error (number of points inside the margin=) To be calculated, lol
# for degree= 2
# margin size= 0.5846926626539689
# error (number of points inside the margin=) To be calculated, lol
# for degree= 3
# margin size= 0.932461056516236
# error (number of points inside the margin=) To be calculated, lol

# %% [markdown]
# ## Second Case :

# %%
#The idea is make x 2-dimensional instead of 1 and in the second dimension we raise x to certain degree
#that makes the data linearly separable 



d = 5


def svmc2(d):
    ## dataPoints
    X = np.array([[1,1],[2,2**d],[5,5**d],[6,6**d],[7,7**d],[8,8**d],[9,9**d],[10,10**d],[11,11**d]])
    ## Labels
    y = np.array([0,1,1,0,0,1,1,1,1])
    svclassifier = SVC(kernel='linear',C=1)
    svclassifier.fit(X, y)


    w =svclassifier.coef_[0]
    I = svclassifier.intercept_
    slope = -w[0]/w[1]
    intercept = I[0]/w[1]
    x1 = np.linspace(1,11,100)
    y1 = slope*x1 - intercept



    plt.plot(x1,y1)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='autumn')

    xx = np.linspace(-5, 5)
    yy = slope * xx - (svclassifier.intercept_[0]) / w[1]

    margin = 1 / np.sqrt(np.sum(svclassifier.coef_ ** 2))
    
    yy_down = y1 - np.sqrt(1 + slope ** 2) * margin
    yy_up = y1 + np.sqrt(1 + slope ** 2) * margin

    
    
    print("margin size=",margin)
    
    print("error (number of points inside the margin=)","To be calculated, lol")
    plt.plot(x1, yy_down, 'k--')
    plt.plot(x1, yy_up, 'k--')
    plt.grid()
    plt.show()

for i in range(1,6):
    print("for degree=",i)
    svmc2(i)
# Out:
# for degree= 1
# margin size= 4.94974746830585
# error (number of points inside the margin=) To be calculated, lol
# for degree= 2
# margin size= 4.482186966202996
# error (number of points inside the margin=) To be calculated, lol
# for degree= 3
# margin size= 6.082180353049715
# error (number of points inside the margin=) To be calculated, lol
# for degree= 4
# margin size= 4.412348760999311
# error (number of points inside the margin=) To be calculated, lol
# for degree= 5
# margin size= 0.7028524342115359
# error (number of points inside the margin=) To be calculated, lol

# %% [markdown]
# ## Case 3

# %%
#The idea is make x 2-dimensional instead of 1 and in the second dimension we raise x to certain degree
#that makes the data linearly separable 

def svmc3(d):
    ## dataPoints
    X = np.array([[1,1**d],[2,2**d],[5,5**d],[6,6**d],[9,9**d],[10,10**d]])
    ## Labels
    y = np.array([0,0,0,0,0,1])

    svclassifier = SVC(kernel='linear',C=1)
    svclassifier.fit(X, y)


    w =svclassifier.coef_[0]
    I = svclassifier.intercept_
    slope = -w[0]/w[1]
    intercept = I[0]/w[1]
    x1 = np.linspace(1,11,100)
    y1 = slope*x1 - intercept



    plt.plot(x1,y1)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=20, cmap='autumn')

    xx = np.linspace(-5, 5)
    yy = slope * xx - (svclassifier.intercept_[0]) / w[1]

    margin = 1 / np.sqrt(np.sum(svclassifier.coef_ ** 2))
    print(margin)
    yy_down = y1 - np.sqrt(1 + slope ** 2) * margin
    yy_up = y1 + np.sqrt(1 + slope ** 2) * margin

    print("margin size=",margin)
    
    print("error (number of points inside the margin=)","To be calculated, lol")
    plt.plot(x1, yy_down, 'k--')
    plt.plot(x1, yy_up, 'k--')
    plt.grid()
    plt.show()

for i in range(1,6):
    print("for degree=",i)
    svmc3(i)
# Out:
# for degree= 1
# 0.7071067811865475
# margin size= 0.7071067811865475
# error (number of points inside the margin=) To be calculated, lol
# for degree= 2
# 9.513148795220223
# margin size= 9.513148795220223
# error (number of points inside the margin=) To be calculated, lol
# for degree= 3
# 135.50092250608483
# margin size= 135.50092250608483
# error (number of points inside the margin=) To be calculated, lol
# for degree= 4
# 1719.5006542599328
# margin size= 1719.5006542599328
# error (number of points inside the margin=) To be calculated, lol
# for degree= 5
# 20475.49985958829
# margin size= 20475.49985958829
# error (number of points inside the margin=) To be calculated, lol

# %% [markdown]
# 3) In Haykin 2ed, P6.14 shows a set of data points corresponding to two classes C1 and C2. Both coordinates x1 and x2 range from -1 to +1. Using the radial-basis function kernel
#
# K(x,t) = exp(-(|| x - t ||^2))
# construct the optimal hyperplane for the following data set.
#
# mypositive=[
# -1/2 3/4+1/16
# -1/2 3/4-1/16
# -3/8 3/4+1/16
# -3/8 3/4-1/16
# -1/4 3/4+1/16
# -1/4 3/4-1/16
# -1/8 1/2+1/16
# -1/8 3/4
# 0 1/2
# 0 3/4
# 1/8 -3/4-3/16
# 1/8 -3/4
# 1/8 -1/2-1/16
# 1/8 -1/2+1/16
# 1/8 1/4
# 1/8 1/4+3/16
# 1/8 1/2+2/16
# 1/4 -3/4-2/16
# 1/4 -1/2-2/16
# 1/4 -1/16
# 1/4 2/16
# 1/4 1/4+1/16
# 1/4 1/2
# 3/8 -1/4-2/16
# 3/8 -3/16
# 3/8 1/16
# 3/8 1/4
# 1/2 -1/16
# ];
#
# mynegative=[ -1/2 1/2
# -3/8 -1/2
# -3/8 1/4+1/16
# -3/8 1/2
# -1/4 -3/4-1/16
# -1/4 -3/4+1/16
# -1/4 -3/16
# -1/4 2/16
# -1/4 1/4+1/16
# -1/4 1/2-1/16
# -1/8 -3/4-2/16
# -1/8 -3/4
# -1/8 -1/2-1/16
# -1/8 -1/4-2/16
# -1/8 -1/4
# -1/8 3/16
# -1/8 1/4+1/16
# 0 -1/4
# 0 1/16
# 1/16 -1/16
# ];
#
# You result classification should looks as the following:
# ![svm_result.jpg](attachment:svm_result.jpg)

# %%
mypositive=[[-1/2 ,3/4+1/16],
                     [-1/2 ,3/4-1/16],
                     [-3/8 ,3/4+1/16],
                     [-3/8 ,3/4-1/16],
                     [-1/4 ,3/4+1/16],
                     [-1/4 ,3/4-1/16],
                     [-1/8 ,1/2+1/16],
                     [-1/8 ,3/4] ,
                     [0 ,1/2] ,
                     [0 ,3/4] ,
                     [1/8 ,-3/4-3/16],
                     [1/8 ,-3/4],
                     [1/8 ,-1/2-1/16],
                     [1/8 ,-1/2+1/16], 
                     [1/8 ,1/4],
                     [1/8 ,1/4+3/16],
                     [1/8 ,1/2+2/16],
                     [1/4 ,-3/4-2/16],
                     [1/4 ,-1/2-2/16],
                     [1/4 ,-1/16],
                     [1/4 ,2/16],
                     [1/4 ,1/4+1/16],
                     [1/4 ,1/2],
                     [3/8 ,-1/4-2/16],
                     [3/8 ,-3/16],
                     [3/8 ,1/16],
                     [3/8 ,1/4],
                     [1/2 ,-1/16]]

# %%
nb_el_pos = np.shape(mypositive)[0]

# %%
mynegative=[[-1/2 ,1/2] ,
                     [-3/8 ,-1/2] ,
                     [-3/8 ,1/4+1/16] ,
                     [-3/8 ,1/2 ],
                     [-1/4 ,-3/4-1/16] ,
                     [-1/4 ,-3/4+1/16] ,
                     [-1/4 ,-3/16] ,
                     [-1/4 ,2/16] ,
                     [-1/4 ,1/4+1/16] ,
                     [-1/4 ,1/2-1/16] ,
                     [-1/8 ,-3/4-2/16] ,
                     [-1/8 ,-3/4] ,
                     [-1/8 ,-1/2-1/16] ,
                     [-1/8 ,-1/4-2/16] ,
                     [-1/8 ,-1/4] ,
                     [-1/8 ,3/16] ,
                     [-1/8 ,1/4+1/16] ,
                     [0 ,-1/4] ,
                     [0 ,1/16] ,
                     [1/16 ,-1/16] ]

# %%
nb_el_neg = np.shape(mynegative)[0]

# %%
for neg in mynegative:
    mypositive.append(neg)

# %%
X = mypositive

# %%
np.shape(X)
# Out:
# (48, 2)

# %%
labelsPositive = np.ones(nb_el_pos)
labelsNegative = -np.ones(nb_el_neg)

# %%
Y = np.hstack((labelsPositive,labelsNegative))

# %%
Y.shape
# Out:
# (48,)

# %%
svclassifier = SVC(kernel='rbf',gamma=np.sqrt(1/2))
svclassifier.fit(X, Y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.7071067811865476,
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(X)
error_rate = sum(y_pred != Y)

# %%
from matplotlib.colors import ListedColormap

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    X = np.array(X)
    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'white')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.4, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                    alpha=0.8, c=cmap(idx),
                    marker=markers[idx], label=cl)

# %%
# Create a SVC classifier using an RBF kernel
svm = SVC(kernel='rbf', random_state=0, gamma=1/np.sqrt(2), C=1)
# Train the classifier
svm.fit(X, Y)

# Visualize the decision boundaries
plot_decision_regions(X, Y, classifier=svm)
plt.legend(loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
